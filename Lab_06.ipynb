# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a51l25/B51Data_Mining/blob/main/Lab_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
data={'category':['A','B','C','A','B']}
df=pd.DataFrame(data)
print(df)
# Out:
#   category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B

# %%
label_encoder=LabelEncoder()
df['Label_Encoded']=label_encoder.fit_transform(df['category'])
print(df)
# Out:
#   category  Label_Encoded
# 0        A              0
# 1        B              1
# 2        C              2
# 3        A              0
# 4        B              1

# %%
one_hot_Encoded=pd.get_dummies(df['category'],prefix='category')
df=pd.concat([df,one_hot_Encoded],axis=1)
print(df)
# Out:
#   category  Label_Encoded  category_A  category_B  category_C
# 0        A              0        True       False       False
# 1        B              1       False        True       False
# 2        C              2       False       False        True
# 3        A              0        True       False       False
# 4        B              1       False        True       False

# %%
data = {'category':['A','A','B','B','C'],'Value':[10,20,10,30,40]}
df = pd.DataFrame(data)
print(df)
# Out:
#   category  Value
# 0        A     10
# 1        A     20
# 2        B     10
# 3        B     30
# 4        C     40

# %%
grouped = df.groupby('category').agg({'Value':['sum','mean']})
print("grouped Data:\n",grouped)
# Out:
# grouped Data:
#           Value
#            sum  mean
# category
# A           30  15.0
# B           40  20.0
# C           40  40.0

# %%
pivot=df.pivot_table(index='category',values='Value',aggfunc=['sum','mean'])
print("Pivot Table:\n",pivot)
# Out:
# Pivot Table:
#             sum  mean
#          Value Value
# category
# A           30  15.0
# B           40  20.0
# C           40  40.0
